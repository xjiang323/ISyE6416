# %%
from gradiant import *

# %%
run()
# Out:
# Starting gradient descent at b = 0, m = 0, error = 2.4278074871184607
# Running...
# After 200 iterations b = 0.5622319697654055, m = 0.12985950397334317, error = 0.7163340664832971
